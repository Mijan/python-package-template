# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys
PROJECT_ROOT = Path('..').resolve()
SRC_PATH = PROJECT_ROOT / 'src'
if str(SRC_PATH) not in sys.path:
    sys.path.append(str(SRC_PATH))

# %% [markdown]
# # Example Notebook
# Simple example notebook that can be used for trying out code, debugging or documentation
